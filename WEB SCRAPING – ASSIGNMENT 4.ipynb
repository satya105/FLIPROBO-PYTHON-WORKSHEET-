# %% [markdown]
# ## WEB SCRAPING

# %% [markdown]
# #### Importing necessary libraries

# %%
import pandas as pd
import time
from bs4 import BeautifulSoup
from selenium import webdriver
import selenium
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException, ElementNotInteractableException
import requests
from selenium.common.exceptions import TimeoutException
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Q1- Scrape the details of most viewed videos on YouTube from Wikipedia.
# #### Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos
# ##### You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
#command for open the automation window of browser

driver1 = webdriver.Chrome(r"C:\Users\lucky\Desktop\chromedriver")

# %%
#getting the wiki page
driver1.get('https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos')

# %%
#creating list of rank , name, artist, upload date, views
rank=[]
name=[]
artist=[]
upload_date=[]
views=[]

#Rank

try:
    Ranks=driver1.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[1]')[:30]
    for i in Ranks:
        rank.append(i.text)
except NoSuchElementException:
    rank.append('-')
    
    
#NAME 
try:
    Name = driver1.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[2]')[:30]
    for i in Name:
        name.append(i.text.split('[')[0][1:-1])
except NoSuchElementException :
    name.append('-')
    
    
#ARTISt
try:
    Artist = driver1.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[3]')[:30]
    for i in Artist:
        artist.append(i.text)
except NoSuchElementException :
    video_uploader_name.append('-')
    
    

#VIEWS
try:
    Views = driver1.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[4]')[:30]
    for i in Views:
        views.append(i.text)
except NoSuchElementException :
    views.append('-')
    
#upload date
try:
    date = driver1.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]/tbody/tr/td[5]')[:30]
    for i in date:
        upload_date.append(i.text)
except NoSuchElementException :
    upload_date.append('-')

# %%
#creating dataframe
df= pd.DataFrame([])
df['Rank']= rank
df['Name']=name
df['Artist']=artist
df['Upload Date']=upload_date
df['Views in Billions']=views

# %%
df
# Out:
#    Rank                                       Name  \
# 0    1.                           Baby Shark Dance
# 1    2.                                  Despacito
# 2    3.                       Johny Johny Yes Papa
# 3    4.                               Shape of You
# 4    5.                              See You Again
# 5    6.                                  Bath Song
# 6    7.                Phonics Song with Two Words
# 7    8.                                Uptown Funk
# 8    9.  Learning Colors – Colorful Eggs on a Farm
# 9   10.   Masha and the Bear – Recipe for Disaster
# 10  11.                              Gangnam Style
# 11  12.                          Wheels on the Bus
# 12  13.                             Dame Tu Cosita
# 13  14.                                      Sugar
# 14  15.                                       Roar
# 15  16.                             Counting Stars
# 16  17.                                      Sorry
# ...

# %%
driver1.close()

# %% [markdown]
# ### Q2- Scrape the details team India’s international fixtures from bcci.tv.
# #### Url = https://www.bcci.tv/
# ##### You need to find following details:
# A) Match title (I.e. 1
# st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
# ##### Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
#command for open the automation window of browser

driver = webdriver.Chrome(r"C:\Users\lucky\Desktop\chromedriver")
time.sleep(2)

# %%
#getting the bcci page

url= "https://www.bcci.tv/"
driver.get(url)

# %%
international_fixture= driver.find_element_by_xpath('html/body/nav/div[1]/div[2]/ul[1]/li[2]/a')
international_fixture.click()

# %%
match_title=[]
try:
    match = driver.find_elements_by_xpath('//span[@class="matchOrderText ng-binding ng-scope"]')
    for i in match:
        match_title.append(i.text)
except NoSuchElementException :
    match_title.append('-')


place=[]
try:
    Place = driver.find_elements_by_xpath('//span[@class="ng-binding ng-scope"]') 
    for i in Place:
        place.append(i.text)
except NoSuchElementException:
    place.append('-')
    

Series=[]
try:
    series= driver.find_elements_by_xpath('//span[@class="ng-binding"]')
    for i in series:
        Series.append(i.text)
except NoSuchElementException :
    Series.append('-')
    
    
Date=[]
try:
    date=driver.find_elements_by_xpath('//div[@class="match-card-left match-schedule"]')
    for i in date:
        Date.append(i.text)
except NoSuchElementException :
    Date.append('-')
    
Time=[]
try:
    time=driver.find_elements_by_xpath('//div[@class="match-card-right match-schedule"]')
    for i in time:
        Time.append(i.text)
except NoSuchElementException :
    Time.append('-')

# %%
#creating the dictionary of the elements
dict= {
    'Date':Date,'Match': match_title,'Series':Series,'Match Location':place,
    }
#table creating with creating a DataFrame
table = pd.DataFrame(dict)

# %%
table
# Out:
#           Date       Match                                   Series  \
# 0  18 AUG 2022   1st ODI -   INDIA TOUR OF ZIMBABWE ODI SERIES 2022
# 1  20 AUG 2022   2nd ODI -   INDIA TOUR OF ZIMBABWE ODI SERIES 2022
# 2  22 AUG 2022   3rd ODI -   INDIA TOUR OF ZIMBABWE ODI SERIES 2022
# 3  28 AUG 2022  1st T20I -                            ASIA CUP 2022
# 4  31 AUG 2022  2nd T20I -                            ASIA CUP 2022
# 5  20 SEP 2022  1st T20I -  AUSTRALIA TOUR OF INDIA T20 SERIES 2022
# 6  23 SEP 2022  2nd T20I -  AUSTRALIA TOUR OF INDIA T20 SERIES 2022
# 7  25 SEP 2022  3rd T20I -  AUSTRALIA TOUR OF INDIA T20 SERIES 2022
#
#                                   Match Location
# 0                            Harare Sports Club,
# 1                            Harare Sports Club,
# 2                            Harare Sports Club,
# 3           Dubai International Cricket Stadium,
# 4           Dubai International Cricket Stadium,
# 5  Punjab Cricket Association IS Bindra Stadium,
# ...

# %% [markdown]
# ### Q3- Scrape the details of selenium exception from guru99.com.
# #### Url = https://www.guru99.com/
# ##### You need to find following details:
# A) Name
# B) Description
# ###### Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
#command for open the automation window of browser
driver = webdriver.Chrome(r"C:\Users\lucky\Desktop\chromedriver")

#getting the guru99 page
Url = "https://www.guru99.com/"
driver.get(Url)

#getting web element and clicking.
driver.find_element_by_xpath('//a[@title="Selenium"]').click()

# %%
driver.find_element_by_xpath('//a[@title="Selenium Exception Handling (Common Exceptions List)"]').click()

# %%
#Creating empty list.
Name=[]
Description=[]
#Creating for loop to scrape data.
name = driver.find_elements_by_xpath('//table[@class="table table-striped"]/tbody/tr/td[1]')
for a in name:
    Name.append(a.text)
    

description= driver.find_elements_by_xpath('//table[@class="table table-striped"]/tbody/tr/td[2]')
for b in description:
    Description.append(b.text)

# %%
len(Name)
# Out:
# 41

# %%
#creating the dictionary of the elements
dict= {'Name': Name, 'Description':Description}
df = pd.DataFrame(dict)
df
# Out:
#                                    Name  \
# 0            ElementNotVisibleException
# 1         ElementNotSelectableException
# 2                NoSuchElementException
# 3                  NoSuchFrameException
# 4               NoAlertPresentException
# 5                 NoSuchWindowException
# 6        StaleElementReferenceException
# 7              SessionNotFoundException
# 8                      TimeoutException
# 9                    WebDriverException
# 10            ConnectionClosedException
# 11     ElementClickInterceptedException
# 12      ElementNotInteractableException
# 13             ErrorInResponseException
# 14  ErrorHandler.UnknownServerException
# 15         ImeActivationFailedException
# 16             ImeNotAvailableException
# 17         InsecureCertificateException
# 18             InvalidArgumentException
# 19         InvalidCookieDomainException
# 20          InvalidCoordinatesException
# 21          InvalidElementStateExceptio
# ...

# %%
driver.close()

# %% [markdown]
# ### Q4- Scrape the details of State-wise GDP of India from statisticstime.com.
# #### Url = http://statisticstimes.com/
# ###### You have to find following details:
# A) Rank
# B) State
# C) GSDP(18-19)
# D) GSDP(17-18)
# E) Share(2017)
# F) GDP($ billion)
# ##### Note: - From statisticstimes home page you have to reach to economy page through code

# %%
#command for open the automation window of browser
driver = webdriver.Chrome(r"C:\Users\lucky\Desktop\chromedriver")

#getting the page
Url = "http://statisticstimes.com/"
driver.get(Url)

# %%
#getting the economy page of india

economy=driver.find_element_by_xpath('//*[@id="top"]/div[2]/div[2]/button')
economy.click()
india=driver.find_element_by_xpath('//*[@id="top"]/div[2]/div[2]/div/a[3]')
india.click()

#getting gdp of indian states
gdp= driver.find_element_by_xpath('//html/body/div[2]/div[2]/div[2]/ul/li[1]/a')
gdp.click()

# %%
#extracting the rank data
Rank=[]
try:
    rank = driver.find_elements_by_xpath('//div[@id="table_id_wrapper"]/table/tbody/tr/td[1]')
    for i in rank :
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append('-')

#getting the state data
State=[]
try:
    state=driver.find_elements_by_xpath('//div[@id="table_id_wrapper"]/table/tbody/tr/td[2]')
    for i in state:
        State.append(i.text)
except NoSuchElementException:
    State.append('-')

    
#getting gsdp(19-20) data
GSDP=[]
try:
    gsdp=driver.find_elements_by_xpath('//div[@id="table_id_wrapper"]/table/tbody/tr/td[3]')
    for i in gsdp:
        GSDP.append(i.text)
except NoSuchElementException:
    GSDP.append('-')
    
    
#extracting gsdp(18-19) data  
GSdp=[]
try:
    gsdp_18= driver.find_elements_by_xpath('//div[@id="table_id_wrapper"]/table/tbody/tr/td[4]')
    for i in gsdp_18:
        GSdp.append(i.text)
except NoSuchElementException:
    GSdp.append('-')
    

#extracting share (18-19) data
Share= []
try:
    share= driver.find_elements_by_xpath('//div[@id="table_id_wrapper"]/table/tbody/tr/td[5]')
    for i in share:
        Share.append(i.text)
except NoSuchElementException:
    Share.append('-')
    
    
#extracting the gdp(billion)
GDP=[]
try:
    gdp= driver.find_elements_by_xpath('//div[@id="table_id_wrapper"]/table/tbody/tr/td[6]')
    for i in gdp:
        GDP.append(i.text)
except NoSuchElementException:
    GDP.append('-')

# %%
#creating the dictionary of the elements
dict= {'Rank': Rank, 'State':State, 'GSDP (19-20)': GSDP, 'GSDP (18-19)': GSdp, 'Share': Share, 'GDP ($billion)': GDP }
df = pd.DataFrame(dict)
df
# Out:
#    Rank                      State GSDP (19-20) GSDP (18-19)   Share  \
# 0     1                Maharashtra            -    2,632,792  13.94%
# 1     2                 Tamil Nadu    1,845,853    1,630,208   8.63%
# 2     3              Uttar Pradesh    1,687,818    1,584,764   8.39%
# 3     4                    Gujarat            -    1,502,899   7.96%
# 4     5                  Karnataka    1,631,977    1,493,127   7.91%
# 5     6                West Bengal    1,253,832    1,089,898   5.77%
# 6     7                  Rajasthan    1,020,989      942,586   4.99%
# 7     8             Andhra Pradesh      972,782      862,957   4.57%
# 8     9                  Telangana      969,604      861,031   4.56%
# 9    10             Madhya Pradesh      906,672      809,592   4.29%
# 10   11                     Kerala            -      781,653   4.14%
# 11   12                      Delhi      856,112      774,870   4.10%
# 12   13                    Haryana      831,610      734,163   3.89%
# ...

# %%
driver.close()

# %% [markdown]
# ### Q5- Scrape the details of trending repositories on Github.com.
# #### Url = https://github.com/
# ##### You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used
# ###### Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
#command for open the automation window of browser
driver = webdriver.Chrome(r"C:\Users\lucky\Desktop\chromedriver")

#getting the page
Url = "https://github.com/"
driver.get(Url)

# %%
#the trending option from Explore menu
trending= driver.find_element_by_xpath('/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul/li[5]/a')
trending.click()

# %%
#extract the data of Repository title 
Repository_title= []
try:
    title= driver.find_elements_by_xpath('//article[@class="Box-row"]/h1/a')
    for i in title:
        Repository_title.append(i.text)
except NoSuchElementException:
    Repository_title.append('_')
    
    
#extracting Repository description
Repository_description=[]
try:
    desr= driver.find_elements_by_xpath('//article[@class="Box-row"]/p')
    for i in desr:
        Repository_description.append(i.text)
except NoSuchElementException:
    Repository_title.append('-')
    

#extracting Contributors count
Contributors_count=[]
try:
    count=driver.find_elements_by_xpath('//article[@class="Box-row"]/div/span[2]')
    for i in count:
        Contributors_count.append(i.text)
except NoSuchElementException:
    Contributors_count.append('-')
    

#extracting data of language used
Language_used=[]
try:
    lang= driver.find_elements_by_xpath('//article[@class="Box-row"]/div[2]/span/span[2]')
    for i in lang:
        Language_used.append(i.text)
except NoSuchElementException:
    Language_used.append('-')

# %%
print(len(Repository_title),len(Repository_description),len(Contributors_count),len(Language_used))
# Out:
# 25 24 25 21

# %%
#creating the dictionary of the elements
dict= {'Repository Title':Repository_title[0:21],'Repository Description':Repository_description[0:21],
       'Contributors Count':Contributors_count[0:21], 'Language Used':Language_used[0:21]
       }
df = pd.DataFrame(dict)
df
# Out:
#                               Repository Title  \
# 0                        toeverything / AFFiNE
# 1        jwasham / coding-interview-university
# 2                              iptv-org / iptv
# 3                              ventoy / Ventoy
# 4                      MarlinFirmware / Marlin
# 5                            Dreamacro / clash
# 6                    arthurspk / guiadevbrasil
# 7           donnemartin / system-design-primer
# 8                            MatrixTM / MHDDoS
# 9                       t3-oss / create-t3-app
# 10                   punk-security / dnsReaper
# 11  juliocesarfort / public-pentesting-reports
# 12                   facebookresearch / ParlAI
# 13                                utmapp / UTM
# 14             theboy181 / switch-ptchtxt-mods
# 15                 Asabeneh / 30-Days-Of-React
# 16                               github / docs
# 17     josephmisiti / awesome-machine-learning
# 18             PKUFlyingPig / cs-self-learning
# ...

# %% [markdown]
# ### Q6. Scrape the details of top 100 songs on billiboard.com.
# #### Url = https:/www.billboard.com/
# ##### You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# ###### Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
#command for open the automation window of browser
driver = webdriver.Chrome(r"C:\Users\lucky\Desktop\chromedriver")

#getting the page
Url = " https:/www.billboard.com/"
driver.get(Url)

# %%
#the hot 100 from charts section
hot_100= driver.find_element_by_xpath('/html/body/div[3]/header/div[2]/div/nav/ul/li[1]/a')
hot_100.click()

# %%
#extracting the song name 
Song_details=[]
Song_name=[]
Song_Artist=[]
Song_Last_rank=[]
Song_Peak_rank=[]
Song_Weeks_on_board=[]
try:
    song= driver.find_elements_by_xpath('//div[@class="o-chart-results-list-row-container"]/ul/li[4]/ul[1]')
    for i in song:
        Song_name.append(i.text.split('\n')[0])
        Song_Artist.append(i.text.split('\n')[1])
        Song_Last_rank.append(i.text.split('\n')[2])
        Song_Peak_rank.append(i.text.split('\n')[3])
        Song_Weeks_on_board.append(i.text.split('\n')[4])
        
except NoSuchElementException:
    print("Unable to fetch details")

# %%
#creating the dictionary of the elements
dict= {'Name':Song_name,'Artist Name': Song_Artist, 'Last Week Rank': Song_Last_rank, 'Peak Rank' : Song_Peak_rank, 'Weeks On Board': Song_Weeks_on_board }
df = pd.DataFrame(dict)
df
# Out:
#                                       Name                    Artist Name  \
# 0                            Break My Soul                        Beyonce
# 1                          About Damn Time                          Lizzo
# 2                                As It Was                   Harry Styles
# 3   Running Up That Hill (A Deal With God)                      Kate Bush
# 4                               Wait For U  Future Featuring Drake & Tems
# ..                                     ...                            ...
# 95                       Until I Found You                Stephen Sanchez
# 96                               Un Ratito                      Bad Bunny
# 97              Best Thing Since Backroads                      Jake Owen
# 98                            La Corriente          Bad Bunny & Tony Dize
# 99            Bzrp Music Sessions, Vol. 52             Bizarrap & Quevedo
#
#    Last Week Rank Peak Rank Weeks On Board
# ...

# %%
driver.close()

# %% [markdown]
# ### Q7-Scrape the details of Data science recruiters from naukri.com.
# #### Url = https://www.naukri.com/hr-recruiters-consultants
# ##### You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
# ###### Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and click on search. All this should be done through code

# %%
#command for open the automation window of browser
driver = webdriver.Chrome(r"C:\Users\lucky\Desktop\chromedriver")

#getting the page
Url = "https://www.naukri.com/hr-recruiters-consultants"
driver.get(Url)

# %%
# Let's navigate to the search bar and Type Data Science in the search bar and click search
search_field_designation=driver.find_element_by_xpath("//input[@class='sugInp']")
search_field_designation.send_keys("Data Science")
driver.find_element_by_xpath("//button[@class='fl qsbSrch blueBtn']").click()

# %%
#extracting name
Name=[]
name= driver.find_elements_by_xpath('//span[@class="fl ellipsis"]')

for i in name:
    Name.append(i.text)
#print(Name)

#extracting designation name
Designation=[]
designation= driver.find_elements_by_xpath('//span[@class="ellipsis clr"]')
for i in designation:
    Designation.append(i.text)
#print(Designation)

#extracting company name
Company=[]
company= driver.find_elements_by_xpath('//p[@class="highlightable"]/a[2]')
for i in company:
    Company.append(i.text)
#print(Company)

#extracting req skills
Skills=[]
skill=driver.find_elements_by_xpath('//div[@class="hireSec highlightable"]')
for i in skill:
    Skills.append(i.text)
#print(Skills)


#extracting location
Location=[]
location=driver.find_elements_by_xpath('//p[@class="highlightable"]/span[2]')
for i in location:
    Location.append(i.text)
#print(Location)

# %%
print(len(Name),len(Designation),len(Company),len(Skills),len(Location))
# Out:
# 50 50 50 50 48

# %%
#creating the dictionary of the elements
dict= {'Name': Name[:48], 'Designation': Designation[:48], 'Company':Company[:48], 'Skills':Skills[:48] ,
       'Location':Location[:48] }
df = pd.DataFrame(dict)
df
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                             Vaishnavi Kudalkar
# 11                                 Priyanka Akiri
# 12                                Kalpana Dumpala
# 13                                        Mubarak
# 14                                 Kushal Rastogi
# 15                             Mahesh Babu Channa
# 16                                   Kapil Devang
# 17                                Sakshi Chhikara
# ...

# %%
driver.close()

# %% [markdown]
# ### Q8. Scrape the details of Highest selling novels.
# #### URL = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare
# ##### You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
#command for open the automation window of browser
driver = webdriver.Chrome(r"C:\Users\lucky\Desktop\chromedriver")

#getting the page
Url = "https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare"
driver.get(Url)

# %%
Book_name=[]
Author_name=[]
Volumes_sold=[]
Publisher=[]
Genre=[]
try:
    Books=driver.find_elements_by_xpath('//table[@class="in-article sortable"]/tbody/tr')
    for i in range(0,99):
        Book_name.append(Books[0].find_elements_by_xpath('//td[2]')[i].text)
        Author_name.append(Books[0].find_elements_by_xpath('//td[3]')[i].text)
        Volumes_sold.append(Books[0].find_elements_by_xpath('//td[4]')[i].text)
        Publisher.append(Books[0].find_elements_by_xpath('//td[5]')[i].text)
        Genre.append(Books[0].find_elements_by_xpath('//td[6]')[i].text)
        
except NoSuchElementException:
    print("Unable to fetch details")
    
# print(Book_name)
# print(Author_name)
# print(Volumes_sold)
# print(Publisher)
# print(Genre)

# %%
#creating the dictionary of the elements
dict= {'Book Name':Book_name,'Author name': Author_name, 'Volumes_sold': Volumes_sold, 'Publisher' : Publisher,
       'Genre':Genre }
df = pd.DataFrame(dict)
df
# Out:
#                                             Book Name       Author name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 94                           Nights of Rain and Stars     Binchy, Maeve
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
#
#    Volumes_sold        Publisher                        Genre
# ...

# %%
driver.close()

# %% [markdown]
# ### Q9. Scrape the details most watched tv series of all time from imdb.com.
# #### Url = https://www.imdb.com/list/ls095964455/
# ##### You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
#command for open the automation window of browser
driver = webdriver.Chrome(r"C:\Users\lucky\Desktop\chromedriver")


# Let's open the URL
driver.get('https://www.imdb.com/list/ls095964455/')
driver.implicitly_wait(3)

# Let's create an empty lists to store the scraping data
Name=[]
Year_Span=[] 
Genre=[] 
Run_Time=[] 
Ratings=[] 
Votes=[]

try:
    name = driver.find_elements_by_xpath('//h3[@class="lister-item-header"]/a')
except NoSuchElementException:
    print("Name element N/a")

for i in name:
    Name.append(i.text)
try:
    year = driver.find_elements_by_xpath('//span[@class="lister-item-year text-muted unbold"]')
except NoSuchElementException:
    print("Year span element N/a")

for i in year:
    Year_Span.append(i.text)
try:
    gen = driver.find_elements_by_xpath('//span[@class="genre"]')
except NoSuchElementException:
    print("Genre element N/a")

for i in gen:
    Genre.append(i.text)
try:
    runtime = driver.find_elements_by_xpath('//span[@class="runtime"]')
except NoSuchElementException:
    print("Runtime element N/a")

    
for i in runtime:
    Run_Time.append(i.text)
try:
    ratings = driver.find_elements_by_xpath('//div[@class="ipl-rating-star small"]')
except NoSuchElementException:
    print("Rating element N/a")

for i in ratings:
    Ratings.append(i.text)
try:
    vote = driver.find_elements_by_xpath('//span[@name="nv"]')
except NoSuchElementException:
    print("Vote element N/a")

for i in vote:
    Votes.append(i.text)

# %%
#creating the dictionary of the elements
dict= {'Name':Name , 'Year Span' : Year_Span, 'Genre': Genre, 'Run Time': Run_Time, 'Ratings': Ratings, 'Votes': Votes }
df = pd.DataFrame(dict)
df
# Out:
#                               Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)                     Drama
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
#    Run Time Ratings      Votes
# 0    57 min     9.2  2,021,439
# ...

# %% [markdown]
# ### Q10. Details of Datasets from UCI machine learning repositories.
# #### Url = https://archive.ics.uci.edu/
# ##### You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
# ###### Note: - from the home page you have to go to the ShowAllDataset page through code.

# %%
#command for open the automation window of browser
driver = webdriver.Chrome(r"C:\Users\lucky\Desktop\chromedriver")

#Let's open the URL
driver.get('https://archive.ics.uci.edu/')
driver.implicitly_wait(3)

#Let's navigate to view all dataset

try:
    dataset=driver.find_element_by_xpath("//span[@class='normal']/b/a")
    driver.get(dataset.get_attribute('href'))
except NoSuchElementException:
    print("Span class normal not avlbl")
    
    
#Let's create an empty lists to store the scraping data

Dataset_Name=[] 
Data_Type=[]
Task=[] 
Attribute_Type=[] 
No_of_Instances=[] 
No_of_Attribute=[] 
Year=[]


try:
    name = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr[2]/td/table/tbody/tr/td[2]/p/b/a')
except NoSuchElementException:
    print("Name element N/a")
for i in name:
    Dataset_Name.append(i.text)


try:
    names = driver.find_elements_by_xpath('//tr[@bgcolor="DDEEFF"]/td/table/tbody/tr/td[2]/p/b/a')
except NoSuchElementException:
    print("Names element N/a")
for i in names:
    Dataset_Name.append(i.text)
    
    
try:
    datatype = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr[2]/td[2]/p')
except NoSuchElementException:
    print("Data Type element N/a")
for i in datatype:
    Data_Type.append(i.text)
    

try:
    task = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr[2]/td[3]/p')
except NoSuchElementException:
    print("Task element N/a")
for i in task:
    Task.append(i.text)
    

try:    
    att = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr[2]/td[4]/p')
except NoSuchElementException:
    print("Attribute element N/a")
for i in att:
    Attribute_Type.append(i.text)
    

try:    
    ins = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr[2]/td[5]/p')
except NoSuchElementException:
    print("Instances element N/a")
for i in ins:
    No_of_Instances.append(i.text)
    

try:    
    no_of_att = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr[2]/td[6]/p')
except NoSuchElementException:
    print("Attribute element N/a")
for i in no_of_att:
    No_of_Attribute.append(i.text)
    
    
try:
    year = driver.find_elements_by_xpath('//table[@border="1"]/tbody/tr[2]/td[7]/p')
except NoSuchElementException:
    print("Year element N/a")
for i in year:
    Year.append(i.text)

    
try:
    datatype = driver.find_elements_by_xpath('//tr[@bgcolor="DDEEFF"]/td[2]/p')
except NoSuchElementException:
    print("Datatype element N/a")
for i in datatype:
    Data_Type.append(i.text)

    
try:
    tsk = driver.find_elements_by_xpath('//tr[@bgcolor="DDEEFF"]/td[3]/p')
except NoSuchElementException:
    print("Task element N/a")
for i in tsk:
    Task.append(i.text)
    
    
try:
    attr = driver.find_elements_by_xpath('//tr[@bgcolor="DDEEFF"]/td[4]/p')
except NoSuchElementException:
    print("Attribute element N/a")
for i in attr:
    Attribute_Type.append(i.text)
    
    
try:
    noi = driver.find_elements_by_xpath('//tr[@bgcolor="DDEEFF"]/td[5]/p')
except NoSuchElementException:
    print("Instance element N/a")
for i in noi:
    No_of_Instances.append(i.text)
    
    
try:
    noa = driver.find_elements_by_xpath('//tr[@bgcolor="DDEEFF"]/td[6]/p')
except NoSuchElementException:
    print("Number of Attribute element N/a")
for i in noa:
    No_of_Attribute.append(i.text)
    
    
try:
    yr = driver.find_elements_by_xpath('//tr[@bgcolor="DDEEFF"]/td[7]/p')
except NoSuchElementException:
    print("Year element N/a")
for i in yr:
    Year.append(i.text)

# %%
#creating the dictionary of the elements
dict= {'Dataset Name': Dataset_Name, 'Data Type':Data_Type, 'Task' : Task, 'Attribute Type': Attribute_Type, 
      'No of Instances': No_of_Instances ,'No of Attribute': No_of_Attribute, 'Year': Year
      }
df = pd.DataFrame(dict)
df
# Out:
#                                           Dataset Name  \
# 0                                              Abalone
# 1                                                Adult
# 2                         Anonymous Microsoft Web Data
# 3                                Artificial Characters
# 4                             Audiology (Standardized)
# ..                                                 ...
# 307  Image Recognition Task Execution Times in Mobi...
# 308                                           REJAFADA
# 309  Influenza outbreak event prediction via Twitte...
# 310                      Maternal Health Risk Data Set
# 311  Image Recognition Task Execution Times in Mobi...
#
#                                 Data Type                  Task  \
# 0                           Multivariate        Classification
# 1                           Multivariate        Classification
# 2                                          Recommender-Systems
# ...
